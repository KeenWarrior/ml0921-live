# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [10, 20, 30]
y = [15, 25, 35]

# %%
plt.plot(x, y, marker='^')

# %%
x = np.linspace(10, 30, 5)

# %%
y = x + 5

# %%
y
# Out:
# array([15., 20., 25., 30., 35.])

# %%
x
# Out:
# array([10., 15., 20., 25., 30.])

# %%
plt.plot(x, y)

# %%
x = np.linspace(-5, 5, 10)

# %%
y = x * x

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)

# %%
import sklearn

from sklearn.datasets import make_blobs

x, y = make_blobs()

# y

plt.scatter(x[:, 0], x[:, 1], c=y)

# %%
x = np.linspace(0, 2*np.pi, 1000)

# %%
y = np.sin(x)

# %%
plt.plot(x, y)

# %%
plt.plot(x, np.cos(x))

# %%
plt.figure()
plt.ylim(-50, 50)
plt.scatter(x, np.tan(x))

plt.figure()
plt.ylim(-50, 50)
plt.scatter(x, np.tan(x))

# %%
plt.figure(figsize=(5, 5))
plt.ylim(-50, 50)
plt.scatter(x, np.tan(x))

# %%
r = 10

# %%
ang = np.linspace(0, 2*np.pi, 100)

x = r * np.cos(ang)
y = r * np.sin(ang)

plt.figure(figsize=(5, 5))
plt.plot(x, y)

# %%
r = np.linspace(0, 200, 1000)

ang = np.linspace(0, 20*np.pi, 1000)

x = r * np.cos(ang)
y = r * np.sin(ang)

plt.figure(figsize=(5, 5))
plt.plot(x, y)

# %%
data = np.random.randn(10000)

# %%
data = np.random.uniform(4, 10, 10000)

# %%
out = plt.hist(data, bins=50)

# %%
x = [10, 20, 10]

# %%
labs = ["Sale", "Budget", "Expected"]

# %%
explod = [.2, 0, 0]

# %%
out = plt.pie(x, labels=labs, explode=explod, startangle=45, shadow=True)

# %%
x = [10, 30, 100]
y = [100, 50, 120]

# %%
plt.bar(x, y, width=10)
# Out:
# <BarContainer object of 3 artists>

# %%
x = np.linspace(0, 2*np.pi, 1000)

# %%
plt.figure()
plt.subplot(2, 2, 1)
plt.plot(x, np.cos(x))
plt.subplot(1, 2, 2)
plt.plot(x, np.tan(x))
plt.subplot(2, 2, 3)
plt.plot(x, np.log(x))
# Out:
# <ipython-input-142-8b57db5326bf>:7: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x, np.log(x))
